# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# the test print text "Hello World

# %%
my_name = "Daria Bystrova"
print("Hello, World!")
print("My name is", my_name)
# Out:
# Hello, World!
# My name is Daria Bystrova
